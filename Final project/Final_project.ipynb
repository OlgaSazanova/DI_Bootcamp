# %%
import pandas as pd

# %%
war_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\ucdp-prio-acd-241-csv\UcdpPrioConflict_v24_1.csv')
pd.set_option('display.max_columns', None)
war_df.head()

#https://ucdp.uu.se/downloads/
# Out:
#    conflict_id       location               side_a side_a_id side_a_2nd  \
# 0        11342          India  Government of India       141        NaN
# 1        11342          India  Government of India       141        NaN
# 2        11343  Egypt, Israel  Government of Egypt       117        NaN
# 3        11343  Egypt, Israel  Government of Egypt       117        NaN
# 4        11343  Egypt, Israel  Government of Egypt       117        NaN
#
#                  side_b side_b_id side_b_2nd  incompatibility territory_name  \
# 0                  GNLA      1163        NaN                1       Garoland
# 1                  GNLA      1163        NaN                1       Garoland
# 2  Government of Israel       121        NaN                1     Suez/Sinai
# 3  Government of Israel       121        NaN                1     Suez/Sinai
# 4  Government of Israel       121        NaN                1     Suez/Sinai
#
# ...

# %%
war_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2686 entries, 0 to 2685
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   conflict_id           2686 non-null   int64
#  1   location              2686 non-null   object
#  2   side_a                2686 non-null   object
#  3   side_a_id             2686 non-null   object
#  4   side_a_2nd            436 non-null    object
#  5   side_b                2686 non-null   object
#  6   side_b_id             2686 non-null   object
#  7   side_b_2nd            137 non-null    object
#  8   incompatibility       2686 non-null   int64
#  9   territory_name        1511 non-null   object
#  10  year                  2686 non-null   int64
#  11  intensity_level       2686 non-null   int64
#  12  cumulative_intensity  2686 non-null   int64
#  13  type_of_conflict      2686 non-null   int64
#  14  start_date            2686 non-null   object
# ...

# %%
war_df2= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\ucdp-onesided-241-csv\OneSided_v24_1.csv')
pd.set_option('display.max_columns', None)
war_df2.head()
# Out:
#    conflict_id  dyad_id  actor_id coalition_components  \
# 0          533     1000       367                  NaN
# 1          533     1000       367                  NaN
# 2          533     1000       367                  NaN
# 3          534     1001       368                  NaN
# 4          535     1002       373                  NaN
#
#                        actor_name                      actor_name_fulltext  \
# 0  Forces of the Caucasus Emirate           Forces of the Caucasus Emirate
# 1  Forces of the Caucasus Emirate           Forces of the Caucasus Emirate
# 2  Forces of the Caucasus Emirate           Forces of the Caucasus Emirate
# 3                        DHD - BW  Dima Halam Daogah - Black Widow faction
# 4                            BLTF              Bodo Liberation Tiger Force
#
#                           actor_name_mothertongue  year  \
# 0  Имарат Кавказ / Имар Кавказ/ Кавказский Эмират  2010
# 1  Имарат Кавказ / Имар Кавказ/ Кавказский Эмират  2011
# ...

# %%
war_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1262 entries, 0 to 1261
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conflict_id              1262 non-null   int64
#  1   dyad_id                  1262 non-null   int64
#  2   actor_id                 1262 non-null   int64
#  3   coalition_components     31 non-null     object
#  4   actor_name               1262 non-null   object
#  5   actor_name_fulltext      1258 non-null   object
#  6   actor_name_mothertongue  871 non-null    object
#  7   year                     1262 non-null   int64
#  8   best_fatality_estimate   1262 non-null   int64
#  9   low_fatality_estimate    1262 non-null   int64
#  10  high_fatality_estimate   1262 non-null   int64
#  11  is_government_actor      1262 non-null   int64
#  12  location                 1262 non-null   object
#  13  gwno_location            1262 non-null   object
# ...

# %%
war_df3= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\ucdp-nonstate-241-csv\Nonstate_v24_1.csv')
pd.set_option('display.max_columns', None)
war_df3.head()
# Out:
#    conflict_id  dyad_id  org side_a_name side_a_name_fulltext  \
# 0         9488    10098    3      Fulani               Fulani
# 1         9637    10247    3    Konianke             Konianke
# 2         9654    10264    3        Arab                 Arab
# 3         9668    10278    3        Arab                 Arab
# 4         9668    10278    3        Arab                 Arab
#
#   side_a_name_mothertongue  side_a_id side_a_components side_a_2nd  \
# 0                   Fulani        607               NaN        NaN
# 1                 Konianke       1713               NaN        NaN
# 2                     Arab       1012               NaN        NaN
# 3                     Arab       1012               NaN        NaN
# 4                     Arab       1012               NaN        NaN
#
#    gwno_a_2nd side_b_name side_b_name_fulltext side_b_name_mothertongue  \
# 0         NaN      Yoruba               Yoruba                   Yoruba
# ...

# %%
war_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1639 entries, 0 to 1638
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   conflict_id               1639 non-null   int64
#  1   dyad_id                   1639 non-null   int64
#  2   org                       1639 non-null   int64
#  3   side_a_name               1639 non-null   object
#  4   side_a_name_fulltext      1627 non-null   object
#  5   side_a_name_mothertongue  1624 non-null   object
#  6   side_a_id                 1639 non-null   int64
#  7   side_a_components         142 non-null    object
#  8   side_a_2nd                21 non-null     object
#  9   gwno_a_2nd                21 non-null     float64
#  10  side_b_name               1639 non-null   object
#  11  side_b_name_fulltext      1632 non-null   object
#  12  side_b_name_mothertongue  1624 non-null   object
# ...

# %%
war_df4= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\ged241-csv\GEDEvent_v24_1.csv')
pd.set_option('display.max_columns', None)
war_df4.head()
# Out:
# C:\Users\Olga_hp\AppData\Local\Temp\ipykernel_5128\484301519.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   war_df4= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\ged241-csv\GEDEvent_v24_1.csv')
#        id               relid  year  active_year code_status  \
# 0  244657  IRQ-2017-1-524-322  2017            1       Clear
# 1  412700  IRQ-2021-1-524-145  2021            1       Clear
# 2  413023  IRQ-2021-1-524-143  2021            1       Clear
# 3  412909  IRQ-2021-1-524-144  2021            1       Clear
# 4  132140    AFG-1989-1-411-2  1989            1       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id  \
# 0                 1               259              259
# 1                 1               259              259
# 2                 1               259              259
# 3                 1               259              259
# ...

# %%
war_df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349733 entries, 0 to 349732
# Data columns (total 49 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 349733 non-null  int64
#  1   relid              349733 non-null  object
#  2   year               349733 non-null  int64
#  3   active_year        349733 non-null  int64
#  4   code_status        349733 non-null  object
#  5   type_of_violence   349733 non-null  int64
#  6   conflict_dset_id   349733 non-null  int64
#  7   conflict_new_id    349733 non-null  int64
#  8   conflict_name      349733 non-null  object
#  9   dyad_dset_id       349733 non-null  int64
#  10  dyad_new_id        349733 non-null  int64
#  11  dyad_name          349733 non-null  object
#  12  side_a_dset_id     349733 non-null  int64
#  13  side_a_new_id      349733 non-null  int64
#  14  side_a             349733 non-null  object
# ...

# %%
war_df5= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\organizedviolencecy-241-csv\organizedviolencecy_v24_1.csv')
pd.set_option('display.max_columns', None)
war_df5.head()
# Out:
#    country_id_cy   country_cy  year_cy region_cy          main_govt_name_cy  \
# 0            700  Afghanistan     1989      Asia  Government of Afghanistan
# 1            700  Afghanistan     1990      Asia  Government of Afghanistan
# 2            700  Afghanistan     1991      Asia  Government of Afghanistan
# 3            700  Afghanistan     1992      Asia  Government of Afghanistan
# 4            700  Afghanistan     1993      Asia  Government of Afghanistan
#
#    sb_exist_cy  sb_dyad_count_cy           sb_dyad_ids_cy  \
# 0            1                 5  724; 726; 727; 729; 732
# 1            1                 5  724; 726; 727; 732; 733
# 2            1                 4       724; 726; 727; 732
# 3            1                 4       724; 726; 727; 732
# 4            1                 4       726; 732; 734; 842
#
#                                     sb_dyad_names_cy  sb_deaths_parties_cy  \
# 0  Government of Afghanistan - Hizb-i Islami-yi A...                  1019
# ...

# %%
happiness_alcohol_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Alcohol\HappinessAlcoholConsumption.csv')
pd.set_option('display.max_columns', None)
happiness_alcohol_df.head()
# Out:
#        Country          Region Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 0      Denmark  Western Europe      north           7.526  928         53.579
# 1  Switzerland  Western Europe      north           7.509  943         79.866
# 2      Iceland  Western Europe      north           7.501  933         60.530
# 3       Norway  Western Europe      north           7.498  951         70.890
# 4      Finland  Western Europe      north           7.413  918         43.433
#
#    Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0             224                81             278
# 1             185               100             280
# 2             233                61              78
# 3             169                71             129
# 4             263               133              97

# %%
happiness_alcohol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           122 non-null    object
#  1   Region            122 non-null    object
#  2   Hemisphere        122 non-null    object
#  3   HappinessScore    122 non-null    float64
#  4   HDI               122 non-null    int64
#  5   GDP_PerCapita     122 non-null    float64
#  6   Beer_PerCapita    122 non-null    int64
#  7   Spirit_PerCapita  122 non-null    int64
#  8   Wine_PerCapita    122 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 8.7+ KB

# %%
happiness_suicide_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\Suicide_rates.csv')
pd.set_option('display.max_columns', None)
happiness_suicide_df.sample(10)
# Out:
#                    country  year     sex          age  suicides_no  \
# 3973                Belize  2001  female  25-34 years          1.0
# 13336              Jamaica  2009    male   5-14 years          1.0
# 31608                 Cuba  2018  female    75+ years         55.0
# 29792              Austria  2020  female   5-14 years          1.0
# 3751               Belgium  2010  female   5-14 years          2.0
# 16600               Mexico  1988    male    75+ years         60.0
# 22472            Singapore  1991    male    75+ years         16.0
# 25613  Trinidad and Tobago  2010    male    75+ years          4.0
# 3271               Belarus  1996  female   5-14 years          3.0
# 30343   Russian Federation  2018  female  15-24 years        270.0
#
#        population  suicides/100k pop             country-year  HDI for year  \
# 3973        20224           4.940000               Belize2001           NaN
# ...

# %%
happiness_suicide_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31756 entries, 0 to 31755
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             31756 non-null  object
#  1   year                31756 non-null  int64
#  2   sex                 31756 non-null  object
#  3   age                 31756 non-null  object
#  4   suicides_no         30556 non-null  float64
#  5   population          31756 non-null  int64
#  6   suicides/100k pop   31756 non-null  float64
#  7   country-year        31756 non-null  object
#  8   HDI for year        12300 non-null  float64
#  9    gdp_for_year ($)   31756 non-null  object
#  10  gdp_per_capita ($)  31756 non-null  float64
#  11  generation          31756 non-null  object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 2.9+ MB

# %%
human_development_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Human Development World\Human Development Index - Full.csv')
pd.set_option('display.max_columns', None)
human_development_df.head()
# Out:
#   ISO3               Country Human Development Groups UNDP Developing Regions  \
# 0  AFG           Afghanistan                      Low                      SA
# 1  AGO                Angola                   Medium                     SSA
# 2  ALB               Albania                     High                     ECA
# 3  AND               Andorra                Very High                     NaN
# 4  ARE  United Arab Emirates                Very High                      AS
#
#    HDI Rank (2021)  Human Development Index (1990)  \
# 0            180.0                           0.273
# 1            148.0                             NaN
# 2             67.0                           0.647
# 3             40.0                             NaN
# 4             26.0                           0.728
#
#    Human Development Index (1991)  Human Development Index (1992)  \
# 0                           0.279                           0.287
# ...

# %%
WHR2015_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2015.csv')
pd.set_option('display.max_columns', None)
WHR2015_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
WHR2016_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2016.csv')
pd.set_option('display.max_columns', None)
WHR2016_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
WHR2017_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2017.csv')
pd.set_option('display.max_columns', None)
WHR2017_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
WHR2018_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2018.csv')
pd.set_option('display.max_columns', None)
WHR2018_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
WHR2019_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2019.csv')
pd.set_option('display.max_columns', None)
WHR2019_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
WHR2020_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2020.csv')
pd.set_option('display.max_columns', None)
WHR2020_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
WHR2021_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2021.csv')
pd.set_option('display.max_columns', None)
WHR2021_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
WHR2022_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2022.csv')
pd.set_option('display.max_columns', None)
WHR2022_df.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %%
WHR2023_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Happiness and Suicide\WHR\WHR2023.csv')
pd.set_option('display.max_columns', None)
WHR2023_df.tail()
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 132  Congo (Kinshasa)         3.207                           0.095
# 133          Zimbabwe         3.204                           0.061
# 134      Sierra Leone         3.138                           0.082
# 135           Lebanon         2.392                           0.044
# 136       Afghanistan         1.859                           0.033
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 132         3.394         3.020                  7.007           0.652
# 133         3.323         3.084                  7.641           0.690
# 134         3.299         2.976                  7.394           0.555
# 135         2.479         2.305                  9.478           0.530
# 136         1.923         1.795                  7.324           0.341
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
loneliness_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Loneliness and Social Connections\self-reported-loneliness-older-adults.csv')
pd.set_option('display.max_columns', None)
loneliness_df.head()
# Out:
#     Entity Code  Year  Self-reported feelings of loneliness among older adults
# 0  Austria  AUT  2005                                                 46
# 1  Belgium  BEL  2005                                                 42
# 2  Denmark  DNK  2005                                                 25
# 3  England  NaN  2018                                                 33
# 4  Finland  FIN  2002                                                 39

# %%
loneliness_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Entity                                                   15 non-null     object
#  1   Code                                                     14 non-null     object
#  2   Year                                                     15 non-null     int64
#  3   Self-reported feelings of loneliness among older adults  15 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 612.0+ bytes

# %%
labor_productivity_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Loneliness and Social Connections\labor-productivity-per-hour-PennWorldTable.csv')
pd.set_option('display.max_columns', None)
labor_productivity_df.head()
# Out:
#       Entity Code  Year  Productivity (PWT 9.1 (2019))
# 0  Argentina  ARG  1950                       3.132358
# 1  Argentina  ARG  1951                       3.153722
# 2  Argentina  ARG  1952                       2.827533
# 3  Argentina  ARG  1953                       2.963201
# 4  Argentina  ARG  1954                       3.045096

# %%
labor_productivity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3373 entries, 0 to 3372
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Entity                         3373 non-null   object
#  1   Code                           3373 non-null   object
#  2   Year                           3373 non-null   int64
#  3   Productivity (PWT 9.1 (2019))  3373 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 105.5+ KB

# %%
labor_productivity_df['Year'].unique()
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017], dtype=int64)

# %%
one_person_households_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Loneliness and Social Connections\one-person-households.csv')
pd.set_option('display.max_columns', None)
one_person_households_df.head()
# Out:
#         Entity Code  Year  Share of one person households
# 0  Afghanistan  AFG  2015                        0.189425
# 1      Albania  ALB  2011                        8.274421
# 2       Angola  AGO  2007                        4.082942
# 3       Angola  AGO  2011                        6.603705
# 4       Angola  AGO  2016                       10.813146

# %%
one_person_households_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 987 entries, 0 to 986
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Entity                          987 non-null    object
#  1   Code                            961 non-null    object
#  2   Year                            987 non-null    int64
#  3   Share of one person households  987 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 31.0+ KB

# %%
one_person_households_df[one_person_households_df['Entity'] == 'Finland']
# Out:
#       Entity Code  Year  Share of one person households
# 257  Finland  FIN  2004                            37.9
# 258  Finland  FIN  2005                            38.3
# 259  Finland  FIN  2006                            38.5
# 260  Finland  FIN  2007                            38.5
# 261  Finland  FIN  2008                            39.2
# 262  Finland  FIN  2009                            39.8
# 263  Finland  FIN  2010                            39.5
# 264  Finland  FIN  2011                            40.1
# 265  Finland  FIN  2012                            40.2
# 266  Finland  FIN  2013                            40.3
# 267  Finland  FIN  2014                            40.8
# 268  Finland  FIN  2015                            40.9
# 269  Finland  FIN  2016                            41.3
# 270  Finland  FIN  2017                            41.6
# 271  Finland  FIN  2018                            43.0

# %%
non_net_users_df = pd.read_csv('non_net_users_prc.csv')
pd.set_option('display.max_columns', None)
non_net_users_df.head()
# Out:
#        country   1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# 0  Afghanistan  100.0  100.0  100.0  100.0  100.0  100.0    NaN    NaN    NaN
# 1       Angola  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0
# 2      Albania  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0   99.9
# 3      Andorra  100.0  100.0  100.0  100.0  100.0  100.0   98.5   97.0   93.1
# 4          UAE  100.0  100.0  100.0  100.0  100.0   99.9   99.6   96.7   93.1
#
#    1999  2000   2001   2002  2003  2004  2005  2006  2007  2008  2009  2010  \
# 0   NaN   NaN  100.0  100.0  99.9  99.9  98.8  97.9  98.1  98.2  96.5  96.0
# 1  99.9  99.9   99.9   99.7  99.6  99.5  98.9  98.5  98.3  98.1  97.7  97.2
# 2  99.9  99.9   99.7   99.6  99.0  97.6  94.0  90.4  85.0  76.1  58.8  55.0
# 3  92.4  89.5   89.5   88.7  86.5  73.2  62.4  51.1  29.1  30.0  21.5  19.0
# 4  85.1  76.4   73.7   71.7  70.5  69.9  60.0  48.0  39.0  37.0  36.0  32.0
#
# ...

# %%
non_net_users_df[net_users_df['country'] == 'Finland']
# Out:
#     country  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  \
# 56  Finland  99.6  98.6  98.1  97.4  95.1  86.1  83.2  80.5  74.5  67.7  62.8
#
#     2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# 56  56.9  37.6  30.8  27.6  25.5  20.3  19.2  16.3  17.5  13.1  11.3  10.1
#
#     2013  2014  2015  2016  2017  2018  2019
# 56  8.49  13.5  13.6  12.3  12.5  11.1  10.4

# %%
press_freedom_df= pd.read_csv(r'C:\Users\Olga_hp\Desktop\Github\DI_Bootcamp\Final project\Press Freedom\Press Freedom Index.csv', encoding='latin1')
pd.set_option('display.max_columns', None)
press_freedom_df.head()
# Out:
#      Year  Country  ISO  Rank  Score        Zone
# 0  2023.0   Norway  NOR   1.0  95.18  UE Balkans
# 1  2023.0  Ireland  IRL   2.0  89.91  UE Balkans
# 2  2023.0  Denmark  DNK   3.0  89.48  UE Balkans
# 3  2023.0   Sweden  SWE   4.0  88.15  UE Balkans
# 4  2023.0  Finland  FIN   5.0  87.94  UE Balkans

# %%
press_freedom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     1979 non-null   float64
#  1   Country  1979 non-null   object
#  2   ISO      1979 non-null   object
#  3   Rank     1979 non-null   float64
#  4   Score    1979 non-null   float64
#  5   Zone     1977 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 93.4+ KB
