# %%
import pandas as pd
import plotly.express as px

# %%
data=pd.read_csv('Sample - Superstore.csv', encoding='latin-1')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# Which states have the most sales?

# %%
top_states = data.groupby('State')['Sales'].sum().sort_values(ascending=False).head().reset_index(name='count')
top_states
# Out:
#           State        count
# 0    California  457687.6315
# 1      New York  310876.2710
# 2         Texas  170188.0458
# 3    Washington  138641.2700
# 4  Pennsylvania  116511.9140

# %%
fig = px.bar(top_states, x='State', y='count', color='State', title="Sales by States")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# What is the difference between New York and California in terms of sales and profit? (Compare the total sales and profit between New York and California.)

# %%
data['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
NY_sales = data[data['State']== 'New York']['Sales'].sum().round().astype(int)
NY_sales
# Out:
# 310876

# %%
NY_profit = data[data['State']== 'New York']['Profit'].sum().round().astype(int)
NY_profit
# Out:
# 74039

# %%
C_sales = data[data['State']== 'California']['Sales'].sum().round().astype(int)
C_sales
# Out:
# 457688

# %%
C_profit = data[data['State']== 'California']['Profit'].sum().round().astype(int)
C_profit
# Out:
# 76381

# %%
data1 = {
    'State': ['New York', 'New York', 'California', 'California'],
    'Category': ['Sales', 'Profit', 'Sales', 'Profit'],
    'Amount': [NY_sales, NY_profit, C_sales, C_profit]
}
df = pd.DataFrame(data1)
df
# Out:
#         State Category  Amount
# 0    New York    Sales  310876
# 1    New York   Profit   74039
# 2  California    Sales  457688
# 3  California   Profit   76381

# %%
fig = px.bar(df, x='State', y='Amount', color='Category', barmode='group',
             title="Compare Sales and Profit for New York and California")
fig.show()
# Out:
# <div>                            <div id="fb252b00-88cc-4a95-b0d8-7e5e6ee8a8bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb252b00-88cc-4a95-b0d8-7e5e6ee8a8bc")) {                    Plotly.newPlot(                        "fb252b00-88cc-4a95-b0d8-7e5e6ee8a8bc",                        [{"alignmentgroup":"True","hovertemplate":"Category=Sales<br>State=%{x}<br>Amount=%{y}<extra></extra>","legendgroup":"Sales","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sales","offsetgroup":"Sales","orientation":"v","showlegend":true,"textposition":"auto","x":["New York","California"],"xaxis":"x","y":[310876,457688],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Profit<br>State=%{x}<br>Amount=%{y}<extra></extra>","lege
# ...

# %% [markdown]
# We see an interesting thing: Profits are almost the same in two states but Sales on California much more than in New York (458k VS 311k). It means that sales in New York are more profitable.

# %% [markdown]
# Who is an outstanding customer in New York?

# %%
data[data['State'] == 'New York'].groupby(['Customer ID', 'Customer Name'])['Sales'].sum().sort_values(ascending = False).head(1)
# Out:
# Customer ID  Customer Name
# TA-21385     Tom Ashbrook     13723.498
# Name: Sales, dtype: float64

# %% [markdown]
# Are there any differences among states in profitability?

# %%
profitability = data.groupby('State')['Profit'].sum().sort_values(ascending = False).reset_index(name='count')
profitability
# Out:
#                    State       count
# 0             California  76381.3871
# 1               New York  74038.5486
# 2             Washington  33402.6517
# 3               Michigan  24463.1876
# 4               Virginia  18597.9504
# 5                Indiana  18382.9363
# 6                Georgia  16250.0433
# 7               Kentucky  11199.6966
# 8              Minnesota  10823.1874
# 9               Delaware   9977.3748
# 10            New Jersey   9772.9138
# 11             Wisconsin   8401.8004
# 12          Rhode Island   7285.6293
# 13              Maryland   7031.1788
# 14         Massachusetts   6785.5016
# 15              Missouri   6436.2105
# 16               Alabama   5786.8253
# 17              Oklahoma   4853.9560
# 18              Arkansas   4008.6871
# 19           Connecticut   3511.4918
# 20                Nevada   3316.7659
# 21           Mississippi   3172.9762
# 22                  Utah   2546.5335
# 23               Vermont   2244.9783
# ...

# %%
fig = px.bar(profitability, x='State', y='count', color='State', title="Profit by States")
fig.show()
# Out:
# <div>                            <div id="6bb913c2-a120-403d-8e16-8dac2ef7496b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bb913c2-a120-403d-8e16-8dac2ef7496b")) {                    Plotly.newPlot(                        "6bb913c2-a120-403d-8e16-8dac2ef7496b",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br>count=%{y}<extra></extra>","legendgroup":"California","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"California","offsetgroup":"California","orientation":"v","showlegend":true,"textposition":"auto","x":["California"],"xaxis":"x","y":[76381.38709999999],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}<br>count=%{y}<extra></extra>","legendgroup":"New York","marker":{"
# ...

# %% [markdown]
# Determine if 20% of the customers contribute to 80% of the profit

# %%
amount_customers = data['Customer ID'].nunique()
amount_customers
# Out:
# 793

# %%
all_profit = data['Profit'].sum()
round(all_profit)
# Out:
# 286397

# %%
round(amount_customers*0.2)
# Out:
# 159

# %%
round(all_profit*0.8)
# Out:
# 229118

# %%
customers_20perc = data.groupby(['Customer ID'])['Profit'].sum().sort_values(ascending = False).head(159)
customers_20perc
# Out:
# Customer ID
# TC-20980    8981.3239
# RB-19360    6976.0959
# SC-20095    5757.4119
# HL-15040    5622.4292
# AB-10105    5444.8055
#               ...
# FH-14350     706.2890
# RW-19630     698.8325
# MC-17845     698.4174
# ML-17395     684.9162
# JG-15115     684.1911
# Name: Profit, Length: 159, dtype: float64

# %%
profit_by_20_perc= customers_20perc.sum()
round(profit_by_20_perc)
# Out:
# 233885

# %% [markdown]
# So we see that we can apply Pareto principle to customers and Profit

# %% [markdown]
# What are the Top 20 cities by Sales ? What about the Top 20 cities by Profit ? Are there any difference among cities in profitability ? (Identify the top 20 cities based on total sales and total profit and analyze differences in profitability among these cities.)

# %%
top_cities_sales = data.groupby('City')['Sales'].sum().sort_values(ascending = False).head(20).reset_index()
top_cities_sales
# Out:
#              City        Sales
# 0   New York City  256368.1610
# 1     Los Angeles  175851.3410
# 2         Seattle  119540.7420
# 3   San Francisco  112669.0920
# 4    Philadelphia  109077.0130
# 5         Houston   64504.7604
# 6         Chicago   48539.5410
# 7       San Diego   47521.0290
# 8    Jacksonville   44713.1830
# 9     Springfield   43054.3420
# 10        Detroit   42446.9440
# 11       Columbus   38706.2430
# 12         Newark   28576.1190
# 13       Columbia   25283.3240
# 14      Lafayette   25036.2000
# 15        Jackson   24963.8580
# 16    San Antonio   21843.5280
# 17     Burlington   21668.0820
# 18      Arlington   20214.5320
# 19         Dallas   20131.9322

# %%
top_cities_profit = data.groupby('City')['Profit'].sum().sort_values(ascending = False).head(20).reset_index()
top_cities_profit
# Out:
#              City      Profit
# 0   New York City  62036.9837
# 1     Los Angeles  30440.7579
# 2         Seattle  29156.0967
# 3   San Francisco  17507.3854
# 4         Detroit  13181.7908
# 5       Lafayette  10018.3876
# 6         Jackson   7581.6828
# 7         Atlanta   6993.6629
# 8     Minneapolis   6824.5846
# 9       San Diego   6377.1960
# 10    Springfield   6200.6974
# 11       Columbus   5897.1013
# 12         Newark   5793.7588
# 13       Columbia   5606.1167
# 14       Richmond   5567.2486
# 15     Providence   5505.6569
# 16      Henderson   4911.8609
# 17      Arlington   4169.6969
# 18       Lakewood   3234.0278
# 19      Milwaukee   2793.0851

# %%
top_cities = pd.merge(top_cities_sales, top_cities_profit, on='City')

top_cities
# Out:
#              City       Sales      Profit
# 0   New York City  256368.161  62036.9837
# 1     Los Angeles  175851.341  30440.7579
# 2         Seattle  119540.742  29156.0967
# 3   San Francisco  112669.092  17507.3854
# 4       San Diego   47521.029   6377.1960
# 5     Springfield   43054.342   6200.6974
# 6         Detroit   42446.944  13181.7908
# 7        Columbus   38706.243   5897.1013
# 8          Newark   28576.119   5793.7588
# 9        Columbia   25283.324   5606.1167
# 10      Lafayette   25036.200  10018.3876
# 11        Jackson   24963.858   7581.6828
# 12      Arlington   20214.532   4169.6969

# %%
fig = px.scatter(top_cities, x='Sales', y='Profit', text='City',
                 title='Sales vs Profit for Top Cities')


fig.update_traces(textposition='top center')


fig.show()
# Out:
# <div>                            <div id="54af6ad0-a1c3-49f9-bbb2-f247b3a85103" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54af6ad0-a1c3-49f9-bbb2-f247b3a85103")) {                    Plotly.newPlot(                        "54af6ad0-a1c3-49f9-bbb2-f247b3a85103",                        [{"hovertemplate":"Sales=%{x}<br>Profit=%{y}<br>City=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["New York City","Los Angeles","Seattle","San Francisco","San Diego","Springfield","Detroit","Columbus","Newark","Columbia","Lafayette","Jackson","Arlington"],"x":[256368.161,175851.34100000001,119540.742,112669.092,47521.029,43054.342,42446.944,38706
# ...

# %% [markdown]
# What are the Top 20 customers by Sales?

# %%
top_customers = data.groupby(['Customer ID', 'Customer Name'])['Sales'].sum().sort_values(ascending = False).head(20).reset_index()
top_customers
# Out:
#    Customer ID       Customer Name      Sales
# 0     SM-20320         Sean Miller  25043.050
# 1     TC-20980        Tamara Chand  19052.218
# 2     RB-19360        Raymond Buch  15117.339
# 3     TA-21385        Tom Ashbrook  14595.620
# 4     AB-10105       Adrian Barton  14473.571
# 5     KL-16645        Ken Lonsdale  14175.229
# 6     SC-20095        Sanjit Chand  14142.334
# 7     HL-15040        Hunter Lopez  12873.298
# 8     SE-20110        Sanjit Engle  12209.438
# 9     CC-12370  Christopher Conant  12129.072
# 10    TS-21370        Todd Sumrall  11891.751
# 11    GT-14710           Greg Tran  11820.120
# 12    BM-11140        Becky Martin  11789.630
# 13    SV-20365         Seth Vernon  11470.950
# 14    CJ-12010     Caroline Jumper  11164.974
# 15    CL-12565         Clay Ludtke  10880.546
# 16    ME-17320       Maria Etezadi  10663.728
# 17    KF-16285      Karen Ferguson  10604.266
# 18    BS-11365        Bill Shonely  10501.653
# ...

# %% [markdown]
# Plot the Cumulative curve in Sales by Customers. Can we apply Pareto principle to customers and Sales ?

# %%
top_customers['Cumulative Sales'] = top_customers['Sales'].cumsum()
top_customers['Cumulative % of Sales'] = top_customers['Cumulative Sales'] / top_customers['Sales'].sum() * 100
top_customers['Cumulative % of Customers'] = (top_customers.index + 1) / len(top_customers) * 100


fig = px.line(top_customers, x='Cumulative % of Customers', y='Cumulative % of Sales',
              title='Cumulative Sales by Customers (Pareto Principle)',
              labels={'Cumulative % of Customers': 'Cumulative % of Customers', 'Cumulative % of Sales': 'Cumulative % of Sales'})


fig.show()
# Out:
# <div>                            <div id="3818797d-4aa9-4171-a243-04a61a686310" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3818797d-4aa9-4171-a243-04a61a686310")) {                    Plotly.newPlot(                        "3818797d-4aa9-4171-a243-04a61a686310",                        [{"hovertemplate":"Cumulative % of Customers=%{x}<br>Cumulative % of Sales=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[5.0,10.0,15.0,20.0,25.0,30.0,35.0,40.0,45.0,50.0,55.00000000000001,60.0,65.0,70.0,75.0,80.0,85.0,90.0,95.0,100.0],"xaxis":"x","y":[9.45343002526216,16.645397844239486,22.351999332663087,27.861658593229066,33.325245922
# ...

# %% [markdown]
# No, we can't apply Pareto principle to customers and Sales

# %% [markdown]
# Based on the analysis, make decisions on which states and cities to prioritize for marketing strategies.

# %% [markdown]
# The state of New York and the city of New York are the most interesting for prioritizing marketing strategies.
