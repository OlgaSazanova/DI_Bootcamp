# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Identify if there are any duplicate rows based on all columns.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no any duplicate rows

# %% [markdown]
# Identify columns in the Titanic dataset with missing values.

# %% [markdown]
# We have missing values in columns: Age, Cabin and Embarked.
# Column Cabin

# %% [markdown]
# I am going delete column Cabin, because we have more than 600 null values in this column and we can't fill this column.

# %%
data = data.drop(columns = 'Cabin', axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %% [markdown]
# Let's fill missing data in Age column with mean values

# %%
data['Age'].fillna(int(data['Age'].mean()), inplace=True) 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB
# C:\Users\olgak\AppData\Local\Temp\ipykernel_14544\895621204.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(int(data['Age'].mean()), inplace=True)

# %%
data['Sex'] = data['Sex'].map({'female':0 , 'male': 1 })
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
data['Embarked']=data['Embarked'].fillna('No information') 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 76.7+ KB

# %% [markdown]
# Create new features, such as ‘Family Size’ from ‘SibSp’ and ‘Parch’, and ‘Title’ extracted from the ‘Name’ column.
# Convert categorical variables into numerical form using techniques like one-hot encoding or label encoding.
# Normalize or standardize numerical features if required.

# %%
data['Family Size'] = data['SibSp']+ data['Parch']
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked  Family Size
# 0         A/5 21171   7.2500        S            1
# 1          PC 17599  71.2833        C            1
# 2  STON/O2. 3101282   7.9250        S            0
# 3            113803  53.1000        S            1
# 4            373450   8.0500        S            0

# %% [markdown]
# Use statistical methods to detect outliers in columns like ‘Fare’ and ‘Age’.
# Decide on a strategy to handle the identified outliers, such as capping, transformation, or removal.
# Implement the chosen strategy and assess its impact on the dataset.

# %%
Q1 = data['Age'].quantile(0.25)
Q3 = data['Age'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers1 = data[(data['Age'] <= lower_bound) & (data['Age'] >= upper_bound)]

# %%
Q1 = data['Fare'].quantile(0.25)
Q3 = data['Fare'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers2 = data[(data['Fare'] <= lower_bound) & (data['Fare'] >= upper_bound)]

# %%
outliers1
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked, Family Size]
# Index: []

# %%
outliers2
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked, Family Size]
# Index: []

# %% [markdown]
# Assess the scale and distribution of numerical columns in the dataset.
# Apply standardization to features with a wide range of values.
# Normalize data that requires a bounded range, like [0, 1].

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data['Fare_normalized'] = scaler.fit_transform(data[['Fare']])

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked  Family Size  Fare_normalized
# 0         A/5 21171   7.2500        S            1         0.014151
# 1          PC 17599  71.2833        C            1         0.139136
# 2  STON/O2. 3101282   7.9250        S            0         0.015469
# 3            113803  53.1000        S            1         0.103644
# 4            373450   8.0500        S            0         0.015713

# %% [markdown]
# Identify categorical columns in the Titanic dataset, such as ‘Sex’ and ‘Embarked’.
# Use one-hot encoding for nominal variables and label encoding for ordinal variables.
# Integrate the encoded features back into the main dataset.
# Hint: Utilize pandas.get_dummies() for one-hot encoding and LabelEncoder from scikit-learn for label encoding.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data2 = data
data2 = pd.get_dummies(data2, columns=['Embarked'], prefix='Embarked')

# Label encode 'Pclass' column
label_encoder = LabelEncoder()
data2['Pclass'] = label_encoder.fit_transform(data2['Pclass'])

# %%
data2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       2
# 1            2         1       0
# 2            3         1       2
# 3            4         1       0
# 4            5         0       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Family Size  Fare_normalized  Embarked_C  \
# 0         A/5 21171   7.2500            1         0.014151       False
# 1          PC 17599  71.2833            1         0.139136        True
# 2  STON/O2. 3101282   7.9250            0         0.015469       False
# 3            113803  53.1000            1         0.103644       False
# 4            373450   8.0500            0         0.015713       False
#
#    Embarked_No information  Embarked_Q  Embarked_S
# 0                    False       False        True
# 1                    False       False       False
# 2                    False       False        True
# 3                    False       False        True
# 4                    False       False        True

# %% [markdown]
# Create age groups (bins) from the ‘Age’ column to categorize passengers into different age categories.
# Apply one-hot encoding to the age groups to convert them into binary features.
# Hint: Use pd.cut() for binning the ‘Age’ column and pd.get_dummies() for one-hot encoding.

# %%
age_bins = [0, 12, 19, 35, 50, 80]
age_labels = ['Child', 'Teenager', 'Young Adult', 'Adult', 'Senior']

data['AgeGroup'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels, right=False)

# One-hot encode the age groups
data = pd.get_dummies(data, columns=['AgeGroup'], prefix='AgeGroup')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked  Family Size  Fare_normalized  \
# 0         A/5 21171   7.2500        S            1         0.014151
# 1          PC 17599  71.2833        C            1         0.139136
# 2  STON/O2. 3101282   7.9250        S            0         0.015469
# 3            113803  53.1000        S            1         0.103644
# 4            373450   8.0500        S            0         0.015713
#
#    AgeGroup_Child  AgeGroup_Teenager  AgeGroup_Young Adult  AgeGroup_Adult  \
# 0           False              False                  True           False
# 1           False              False                 False            True
# 2           False              False                  True           False
# 3           False              False                 False            True
# 4           False              False                 False            True
#
#    AgeGroup_Senior
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
